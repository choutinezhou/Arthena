# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import sklearn.model_selection as ms

# random forest package
from sklearn.ensemble import RandomForestRegressor

# xgBoost package
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder


# print("xgboost", xgboost.__version__)

# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina'

# %%
# load data 
df = pd.read_csv("data.csv",encoding="latin-1")

# %%
print (df.shape)
df.describe()
# Out:
# (107578, 18)
#        artist_birth_year  artist_death_year  estimate_high  estimate_low  \
# count      107578.000000       71186.000000   6.840400e+04  6.840900e+04
# mean         1916.697011        1979.876352   1.308885e+05  9.323845e+04
# std            29.645913          27.163922   7.857577e+05  5.450646e+05
# min          1824.000000        1898.000000   0.000000e+00  0.000000e+00
# 25%          1899.000000        1968.000000   5.000000e+03  4.000000e+03
# 50%          1925.000000        1986.000000   1.500000e+04  1.000000e+04
# 75%          1937.000000        2004.000000   6.000000e+04  4.000000e+04
# max          1977.000000        2013.000000   6.000000e+07  4.000000e+07
#
#        hammer_price  measurement_depth_cm  measurement_height_cm  \
# count  1.012540e+05         107578.000000          107578.000000
# mean   8.765909e+04              3.015979              67.641823
# std    5.898940e+05             16.889542              74.558581
# min   -1.000000e+00              0.000000               0.000000
# 25%    3.000000e+03              0.000000              28.000000
# 50%    1.200000e+04              0.000000              51.000000
# 75%    4.250000e+04              0.000000              84.000000
# max    7.850000e+07            899.000000           10993.000000
#
#        measurement_width_cm
# count         107578.000000
# mean              65.471063
# std               70.252308
# min                0.000000
# 25%               25.000000
# 50%               49.000000
# 75%               81.000000
# max             5225.000000

# %%
# preview the data
df.head(10)
# Out:
#    artist_birth_year  artist_death_year  artist_name artist_nationality  \
# 0               1902             1982.0  Wifredo Lam              Cuban
# 1               1902             1982.0  Wifredo Lam              Cuban
# 2               1902             1982.0  Wifredo Lam              Cuban
# 3               1902             1982.0  Wifredo Lam              Cuban
# 4               1902             1982.0  Wifredo Lam              Cuban
# 5               1902             1982.0  Wifredo Lam              Cuban
# 6               1902             1982.0  Wifredo Lam              Cuban
# 7               1902             1982.0  Wifredo Lam              Cuban
# 8               1902             1982.0  Wifredo Lam              Cuban
# 9               1902             1982.0  Wifredo Lam              Cuban
#
#                auction_date              category currency edition  \
# 0  1987-11-18T01:00:00.000Z              Painting      USD     NaN
# 1  2005-06-12T00:00:00.000Z              Painting      EUR     NaN
# 2  1994-05-17T00:00:00.000Z              Painting      USD     NaN
# 3  1987-05-19T00:00:00.000Z          Unclassified      USD     NaN
# 4  2002-09-19T04:00:00.000Z          Unclassified      USD     NaN
# 5  2009-06-02T22:00:00.000Z          Unclassified      EUR     NaN
# 6  2015-03-26T00:00:00.000Z  Drawing & Watercolor      EUR     NaN
# 7  2006-11-20T01:00:00.000Z          Unclassified      USD     NaN
# 8  2008-09-14T00:00:00.000Z          Unclassified      USD     NaN
# 9  1990-11-20T01:00:00.000Z             Sculpture      USD     NaN
#
#    estimate_high  estimate_low  hammer_price    location  \
# 0            NaN           NaN      280000.0    New York
# 1            NaN           NaN       30000.0  Versailles
# 2            NaN           NaN       95000.0    New York
# 3            NaN           NaN        2800.0    New York
# 4         2500.0        1500.0        1300.0         NaN
# 5          400.0         300.0           NaN         NaN
# 6            NaN           NaN          -1.0       Paris
# 7        40000.0       30000.0       30000.0    New York
# 8        12000.0       10000.0        5000.0  Cincinnati
# 9            NaN           NaN        4000.0    New York
#
#                                materials  measurement_depth_cm  \
# 0                          oil on canvas                     0
# 1                         Works on Paper                     0
# 2                          oil on canvas                     0
# 3                         Works on Paper                     0
# 4                                    NaN                     0
# 5                                    NaN                     0
# 6  wax crayon and ballpoint pen on paper                     0
# 7                       oil and charcoal                     0
# 8    pen and colored pencil on newsprint                     0
# 9                              Sculpture                    13
#
#    measurement_height_cm  measurement_width_cm  \
# 0                    102                   127
# 1                     51                    41
# 2                     79                   102
# 3                     33                    23
# 4                      0                     0
# 5                      0                     0
# 6                     88                   124
# 7                     46                    36
# 8                     36                    28
# 9                     38                    43
#
#                              title  year_of_execution
# 0                        The night               1944
# 1                         Untitled               1964
# 2                            idols               1955
# 3                            Camel               1973
# 4                      WIFREDO LAM                NaN
# 5                                0                NaN
# 6  Untitled ( Three Compositions )               1960
# 7                            Totem               1972
# 8           Untitled (Horse woman)  Circa\r\t\t\t1953
# 9                             till               1977

# %%
# check data types
df.dtypes
# Out:
# artist_birth_year          int64
# artist_death_year        float64
# artist_name               object
# artist_nationality        object
# auction_date              object
# category                  object
# currency                  object
# edition                   object
# estimate_high            float64
# estimate_low             float64
# hammer_price             float64
# location                  object
# materials                 object
# measurement_depth_cm       int64
# measurement_height_cm      int64
# measurement_width_cm       int64
# title                     object
# year_of_execution         object
# dtype: object

# %% [markdown]
# # Missing Values

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# artist_birth_year         0.000000
# artist_death_year        33.828478
# artist_name               0.000000
# artist_nationality        0.000000
# auction_date              0.000000
# category                  0.000000
# currency                  0.000000
# edition                  87.566231
# estimate_high            36.414509
# estimate_low             36.409861
# hammer_price              5.878525
# location                 16.587964
# materials                 1.709457
# measurement_depth_cm      0.000000
# measurement_height_cm     0.000000
# measurement_width_cm      0.000000
# title                     0.427597
# year_of_execution        25.804533
# dtype: float64

# %% [markdown]
# #### To visualize the missingness

# %%
df_na=(df.isnull().sum() / len(df)) * 100  

f, ax = plt.subplots(figsize=(12, 8))
plt.xticks(rotation='90')
sns.barplot(x=df_na.index, y=df_na)
ax.set(title='Percent missing data by feature', ylabel='% missing')
# Out:
# [Text(0,0.5,'% missing'), Text(0.5,1,'Percent missing data by feature')]
